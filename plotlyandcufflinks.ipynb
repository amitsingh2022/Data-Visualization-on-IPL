# %%
import seaborn as sns
import cufflinks as cf
from plotly.offline import iplot

# %%
! pip install cufflinks
# Out:
# Collecting cufflinks
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# Requirement already satisfied: numpy>=1.9.2 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from cufflinks) (2.2.6)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from cufflinks) (2.2.3)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from cufflinks) (6.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Using cached colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from cufflinks) (80.8.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from cufflinks) (9.2.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from cufflinks) (8.1.7)
# Requirement already satisfied: colorama in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: decorator in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from plotly>=4.1.1->cufflinks) (2.2.0)
# Requirement already satisfied: packaging in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from plotly>=4.1.1->cufflinks) (25.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=5.3.0->cufflinks) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=5.3.0->cufflinks) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\amit\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=5.3.0->cufflinks) (0.2.3)
# Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Installing collected packages: colorlover, cufflinks
#
#    -------------------- ------------------- 1/2 [cufflinks]
#    -------------------- ------------------- 1/2 [cufflinks]
#    -------------------- ------------------- 1/2 [cufflinks]
#    ---------------------------------------- 2/2 [cufflinks]
#
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
