# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Matplotlib Basics

# %%
x = np.linspace(0,5,11)
x 
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title('Graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# ## Subplot in Matplotlib

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(x **2,x **2)
plt.subplot(2,2,4)
plt.plot(x,x **0.5)

# %% [markdown]
# ## Object Orinted Way

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(x,y)
axes1.set_title('Graph 1') 
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes2.plot(y,x)

# %% [markdown]
# ## Types of Plot

# %%
plt.scatter(x,y)

# %%
plt.hist(y)
# Out:
# (array([4., 1., 1., 1., 1., 0., 1., 0., 1., 1.]),
#  array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot (y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17f340b4550>,
#   <matplotlib.lines.Line2D at 0x17f340b4690>],
#  'caps': [<matplotlib.lines.Line2D at 0x17f340b47d0>,
#   <matplotlib.lines.Line2D at 0x17f340b4910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x17f340b4410>],
#  'medians': [<matplotlib.lines.Line2D at 0x17f340b4a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17f340b4b90>],
#  'means': []}

# %% [markdown]
# ## Image Download

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,1,1])
ax.plot(x,y)
ax.set_title('Graph')
plt.savefig('graph.png')

# %% [markdown]
# ## Working with Image

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('graph.png')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %% [markdown]
# ## Optional Designing

# %%
plt.plot(x,y, color='red')
